# %% [markdown]
# <a href="https://colab.research.google.com/github/salgudekomal945-ops/my-colab-work/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
txt = "Company12"
name = txt.isalnum()
print(name)
# Out:
# True

# %%
txt = '5000'
num = txt.isdigit()
print(num)
# Out:
# True

# %%
names = ['John' ,'Peter', 'Vicky']
joined = "-".join(names)
print(joined)
# Out:
# John-Peter-Vicky

# %%
txt = "I love sports"
result = txt.replace("sports", "cricket")
print(result)
# Out:
# I love cricket

# %%
txt = "Hello, welcome to my world."
start = txt.startswith("Hello")
end = txt.endswith(".")
print(start)
print(end)
# Out:
# True
# True

# %%
a, b = 200, 500
if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
aman, vinod = 90, 80
if vinod>aman:
  print("vinod scores greater than aman")
elif aman== vinod:
  print("aman and vinod score equal")
else :
  print("aman scores greater than vinod")
# Out:
# aman scores greater than vinod

# %%
marks = 28
if marks>35:
  print("Pass")
  if marks>60:
    print("Distinction")
  else:
    print("Midrange")
else:
  print("Sadly, Faiil")
# Out:
# Sadly, Faiil
