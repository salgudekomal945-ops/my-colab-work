# %% [markdown]
# <a href="https://colab.research.google.com/github/salgudekomal945-ops/my-colab-work/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame({'team':['A','A','A','A','B','B','B','B'],
                     'points':[10,10,12,12,15,17,20,20],
                     'assist':[5,5,7,9,12,9,6,6]})

# %%
data
# Out:
#   team  points  assist
# 0    A      10       5
# 1    A      10       5
# 2    A      12       7
# 3    A      12       9
# 4    B      15      12
# 5    B      17       9
# 6    B      20       6
# 7    B      20       6

# %%
data[data.duplicated()]
# Out:
#   team  points  assist
# 1    A      10       5
# 7    B      20       6

# %%
#Boolean
data.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# dtype: bool

# %%
data[data.duplicated('team')]
# Out:
#   team  points  assist
# 1    A      10       5
# 2    A      12       7
# 3    A      12       9
# 5    B      17       9
# 6    B      20       6
# 7    B      20       6

# %%
data[data.duplicated(['team','points'])]
# Out:
#   team  points  assist
# 1    A      10       5
# 3    A      12       9
# 7    B      20       6

# %%
data.drop_duplicates()
# Out:
#   team  points  assist
# 0    A      10       5
# 2    A      12       7
# 3    A      12       9
# 4    B      15      12
# 5    B      17       9
# 6    B      20       6

# %%
data.drop_duplicates('team')
# Out:
#   team  points  assist
# 0    A      10       5
# 4    B      15      12

# %%
data.drop_duplicates(['team','points'])
# Out:
#   team  points  assist
# 0    A      10       5
# 2    A      12       7
# 4    B      15      12
# 5    B      17       9
# 6    B      20       6

# %%
data.drop_duplicates(['team','points','assist'])
# Out:
#   team  points  assist
# 0    A      10       5
# 2    A      12       7
# 3    A      12       9
# 4    B      15      12
# 5    B      17       9
# 6    B      20       6
